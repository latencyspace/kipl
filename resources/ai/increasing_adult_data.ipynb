# %%
import pandas as pd
import numpy as np

# %%
file_path = "edited_adult_food.csv"

# %%
df = pd.read_csv(file_path)

# %%
display(df)
# Out:
#      food_name ingredient_name  ingredient_gram  calorie  protein   fat  \
# 0          참꼬막             참꼬막                1    90.79    12.47  2.50
# 1          NaN              쪽파                3      NaN      NaN   NaN
# 2          NaN              마늘                2      NaN      NaN   NaN
# 3          NaN             진간장                5      NaN      NaN   NaN
# 4          NaN             매실청                1      NaN      NaN   NaN
# ..         ...             ...              ...      ...      ...   ...
# 495        NaN              설탕                3      NaN      NaN   NaN
# 496        NaN             진간장                1      NaN      NaN   NaN
# 497  풋고추 된장 무침              고추                4   123.64     2.37  7.35
# 498        NaN              된장                1      NaN      NaN   NaN
# 499        NaN              쌈장                1      NaN      NaN   NaN
#
#      carbohydrate
# 0            4.59
# 1             NaN
# 2             NaN
# 3             NaN
# ...

# %%
df_copy = df.copy()

# %%
df_copy.index = range(df.shape[0], df.shape[0] + df_copy.shape[0])

# %%
display(df)
# Out:
#      food_name ingredient_name  ingredient_gram  calorie  protein   fat  \
# 0          참꼬막             참꼬막                1    90.79    12.47  2.50
# 1          NaN              쪽파                3      NaN      NaN   NaN
# 2          NaN              마늘                2      NaN      NaN   NaN
# 3          NaN             진간장                5      NaN      NaN   NaN
# 4          NaN             매실청                1      NaN      NaN   NaN
# ..         ...             ...              ...      ...      ...   ...
# 495        NaN              설탕                3      NaN      NaN   NaN
# 496        NaN             진간장                1      NaN      NaN   NaN
# 497  풋고추 된장 무침              고추                4   123.64     2.37  7.35
# 498        NaN              된장                1      NaN      NaN   NaN
# 499        NaN              쌈장                1      NaN      NaN   NaN
#
#      carbohydrate
# 0            4.59
# 1             NaN
# 2             NaN
# 3             NaN
# ...

# %%
columns_to_convert = ['calorie', 'protein', 'fat', 'carbohydrate']

df_copy[columns_to_convert] = df_copy[columns_to_convert].replace([np.inf, -np.inf], np.nan)
# df_copy[columns_to_convert] = df_copy[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
for col in columns_to_convert:
    df_copy[col] = df_copy[col].apply(lambda x: int(x) if pd.notna(x) else x)

# %%
display(df_copy)
# Out:
#      food_name ingredient_name  ingredient_gram  calorie  protein  fat  \
# 500        참꼬막             참꼬막                1     90.0     12.0  2.0
# 501        NaN              쪽파                3      NaN      NaN  NaN
# 502        NaN              마늘                2      NaN      NaN  NaN
# 503        NaN             진간장                5      NaN      NaN  NaN
# 504        NaN             매실청                1      NaN      NaN  NaN
# ..         ...             ...              ...      ...      ...  ...
# 995        NaN              설탕                3      NaN      NaN  NaN
# 996        NaN             진간장                1      NaN      NaN  NaN
# 997  풋고추 된장 무침              고추                4    123.0      2.0  7.0
# 998        NaN              된장                1      NaN      NaN  NaN
# 999        NaN              쌈장                1      NaN      NaN  NaN
#
#      carbohydrate
# 500           4.0
# 501           NaN
# 502           NaN
# 503           NaN
# ...

# %%
df = pd.concat([df, df_copy])

# %%
display(df)
# Out:
#      food_name ingredient_name  ingredient_gram  calorie  protein  fat  \
# 0          참꼬막             참꼬막                1    90.79    12.47  2.5
# 1          NaN              쪽파                3      NaN      NaN  NaN
# 2          NaN              마늘                2      NaN      NaN  NaN
# 3          NaN             진간장                5      NaN      NaN  NaN
# 4          NaN             매실청                1      NaN      NaN  NaN
# ..         ...             ...              ...      ...      ...  ...
# 995        NaN              설탕                3      NaN      NaN  NaN
# 996        NaN             진간장                1      NaN      NaN  NaN
# 997  풋고추 된장 무침              고추                4   123.00     2.00  7.0
# 998        NaN              된장                1      NaN      NaN  NaN
# 999        NaN              쌈장                1      NaN      NaN  NaN
#
#      carbohydrate
# 0            4.59
# 1             NaN
# 2             NaN
# 3             NaN
# ...

# %%
start_row = 0
end_row = 1000

copied_data = df.iloc[start_row:end_row].copy()
data = pd.concat([df, copied_data], ignore_index=True)

# %%
display(data)
# Out:
#       food_name ingredient_name  ingredient_gram  calorie  protein  fat  \
# 0           참꼬막             참꼬막                1    90.79    12.47  2.5
# 1           NaN              쪽파                3      NaN      NaN  NaN
# 2           NaN              마늘                2      NaN      NaN  NaN
# 3           NaN             진간장                5      NaN      NaN  NaN
# 4           NaN             매실청                1      NaN      NaN  NaN
# ...         ...             ...              ...      ...      ...  ...
# 1995        NaN              설탕                3      NaN      NaN  NaN
# 1996        NaN             진간장                1      NaN      NaN  NaN
# 1997  풋고추 된장 무침              고추                4   123.00     2.00  7.0
# 1998        NaN              된장                1      NaN      NaN  NaN
# 1999        NaN              쌈장                1      NaN      NaN  NaN
#
#       carbohydrate
# 0             4.59
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[1000:1999, column] = data.loc[1000:1999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
display(data)
# Out:
#       food_name ingredient_name  ingredient_gram  calorie  protein  fat  \
# 0           참꼬막             참꼬막                1    90.79    12.47  2.5
# 1           NaN              쪽파                3      NaN      NaN  NaN
# 2           NaN              마늘                2      NaN      NaN  NaN
# 3           NaN             진간장                5      NaN      NaN  NaN
# 4           NaN             매실청                1      NaN      NaN  NaN
# ...         ...             ...              ...      ...      ...  ...
# 1995        NaN              설탕                3      NaN      NaN  NaN
# 1996        NaN             진간장                1      NaN      NaN  NaN
# 1997  풋고추 된장 무침              고추                4   124.00     3.00  8.0
# 1998        NaN              된장                1      NaN      NaN  NaN
# 1999        NaN              쌈장                1      NaN      NaN  NaN
#
#       carbohydrate
# 0             4.59
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
data_copy = data.copy()

# %%
data_copy.index = range(data.shape[0], data.shape[0] + data_copy.shape[0])

# %%
data = pd.concat([data, data_copy])

# %%
display(data)
# Out:
#       food_name ingredient_name  ingredient_gram  calorie  protein  fat  \
# 0           참꼬막             참꼬막                1    90.79    12.47  2.5
# 1           NaN              쪽파                3      NaN      NaN  NaN
# 2           NaN              마늘                2      NaN      NaN  NaN
# 3           NaN             진간장                5      NaN      NaN  NaN
# 4           NaN             매실청                1      NaN      NaN  NaN
# ...         ...             ...              ...      ...      ...  ...
# 3995        NaN              설탕                3      NaN      NaN  NaN
# 3996        NaN             진간장                1      NaN      NaN  NaN
# 3997  풋고추 된장 무침              고추                4   124.00     3.00  8.0
# 3998        NaN              된장                1      NaN      NaN  NaN
# 3999        NaN              쌈장                1      NaN      NaN  NaN
#
#       carbohydrate
# 0             4.59
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[2000:3999, column] = data.loc[2000:3999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
display(data)
# Out:
#       food_name ingredient_name  ingredient_gram  calorie  protein  fat  \
# 0           참꼬막             참꼬막                1    90.79    12.47  2.5
# 1           NaN              쪽파                3      NaN      NaN  NaN
# 2           NaN              마늘                2      NaN      NaN  NaN
# 3           NaN             진간장                5      NaN      NaN  NaN
# 4           NaN             매실청                1      NaN      NaN  NaN
# ...         ...             ...              ...      ...      ...  ...
# 3995        NaN              설탕                3      NaN      NaN  NaN
# 3996        NaN             진간장                1      NaN      NaN  NaN
# 3997  풋고추 된장 무침              고추                4   125.00     4.00  9.0
# 3998        NaN              된장                1      NaN      NaN  NaN
# 3999        NaN              쌈장                1      NaN      NaN  NaN
#
#       carbohydrate
# 0             4.59
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
data_copy = data.copy()

# %%
data_copy.index = range(data.shape[0], data.shape[0] + data_copy.shape[0])

# %%
data = pd.concat([data, data_copy])

# %%
display(data)
# Out:
#       food_name ingredient_name  ingredient_gram  calorie  protein  fat  \
# 0           참꼬막             참꼬막                1    90.79    12.47  2.5
# 1           NaN              쪽파                3      NaN      NaN  NaN
# 2           NaN              마늘                2      NaN      NaN  NaN
# 3           NaN             진간장                5      NaN      NaN  NaN
# 4           NaN             매실청                1      NaN      NaN  NaN
# ...         ...             ...              ...      ...      ...  ...
# 7995        NaN              설탕                3      NaN      NaN  NaN
# 7996        NaN             진간장                1      NaN      NaN  NaN
# 7997  풋고추 된장 무침              고추                4   125.00     4.00  9.0
# 7998        NaN              된장                1      NaN      NaN  NaN
# 7999        NaN              쌈장                1      NaN      NaN  NaN
#
#       carbohydrate
# 0             4.59
# 1              NaN
# 2              NaN
# 3              NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[4000:7999, column] = data.loc[4000:7999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
data_copy = data.copy()

# %%
data_copy.index = range(data.shape[0], data.shape[0] + data_copy.shape[0])

# %%
data = pd.concat([data, data_copy])

# %%
display(data)
# Out:
#        food_name ingredient_name  ingredient_gram  calorie  protein   fat  \
# 0            참꼬막             참꼬막                1    90.79    12.47   2.5
# 1            NaN              쪽파                3      NaN      NaN   NaN
# 2            NaN              마늘                2      NaN      NaN   NaN
# 3            NaN             진간장                5      NaN      NaN   NaN
# 4            NaN             매실청                1      NaN      NaN   NaN
# ...          ...             ...              ...      ...      ...   ...
# 15995        NaN              설탕                3      NaN      NaN   NaN
# 15996        NaN             진간장                1      NaN      NaN   NaN
# 15997  풋고추 된장 무침              고추                4   126.00     5.00  10.0
# 15998        NaN              된장                1      NaN      NaN   NaN
# 15999        NaN              쌈장                1      NaN      NaN   NaN
#
#        carbohydrate
# 0              4.59
# 1               NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[8000:15999, column] = data.loc[8000:15999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
data_copy = data.copy()

# %%
data_copy.index = range(data.shape[0], data.shape[0] + data_copy.shape[0])

# %%
data = pd.concat([data, data_copy])

# %%
display(data)
# Out:
#        food_name ingredient_name  ingredient_gram  calorie  protein   fat  \
# 0            참꼬막             참꼬막                1    90.79    12.47   2.5
# 1            NaN              쪽파                3      NaN      NaN   NaN
# 2            NaN              마늘                2      NaN      NaN   NaN
# 3            NaN             진간장                5      NaN      NaN   NaN
# 4            NaN             매실청                1      NaN      NaN   NaN
# ...          ...             ...              ...      ...      ...   ...
# 31995        NaN              설탕                3      NaN      NaN   NaN
# 31996        NaN             진간장                1      NaN      NaN   NaN
# 31997  풋고추 된장 무침              고추                4   127.00     6.00  11.0
# 31998        NaN              된장                1      NaN      NaN   NaN
# 31999        NaN              쌈장                1      NaN      NaN   NaN
#
#        carbohydrate
# 0              4.59
# 1               NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[16000:31999, column] = data.loc[16000:31999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
data_copy = data.copy()

# %%
data_copy.index = range(data.shape[0], data.shape[0] + data_copy.shape[0])

# %%
data = pd.concat([data, data_copy])

# %%
display(data)
# Out:
#        food_name ingredient_name  ingredient_gram  calorie  protein   fat  \
# 0            참꼬막             참꼬막                1    90.79    12.47   2.5
# 1            NaN              쪽파                3      NaN      NaN   NaN
# 2            NaN              마늘                2      NaN      NaN   NaN
# 3            NaN             진간장                5      NaN      NaN   NaN
# 4            NaN             매실청                1      NaN      NaN   NaN
# ...          ...             ...              ...      ...      ...   ...
# 63995        NaN              설탕                3      NaN      NaN   NaN
# 63996        NaN             진간장                1      NaN      NaN   NaN
# 63997  풋고추 된장 무침              고추                4   128.00     7.00  12.0
# 63998        NaN              된장                1      NaN      NaN   NaN
# 63999        NaN              쌈장                1      NaN      NaN   NaN
#
#        carbohydrate
# 0              4.59
# 1               NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[32000:63999, column] = data.loc[32000:63999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
data_copy = data.copy()

# %%
data_copy.index = range(data.shape[0], data.shape[0] + data_copy.shape[0])

# %%
data = pd.concat([data, data_copy])

# %%
display(data)
# Out:
#         food_name ingredient_name  ingredient_gram  calorie  protein   fat  \
# 0             참꼬막             참꼬막                1    90.79    12.47   2.5
# 1             NaN              쪽파                3      NaN      NaN   NaN
# 2             NaN              마늘                2      NaN      NaN   NaN
# 3             NaN             진간장                5      NaN      NaN   NaN
# 4             NaN             매실청                1      NaN      NaN   NaN
# ...           ...             ...              ...      ...      ...   ...
# 127995        NaN              설탕                3      NaN      NaN   NaN
# 127996        NaN             진간장                1      NaN      NaN   NaN
# 127997  풋고추 된장 무침              고추                4   129.00     8.00  13.0
# 127998        NaN              된장                1      NaN      NaN   NaN
# 127999        NaN              쌈장                1      NaN      NaN   NaN
#
#         carbohydrate
# 0               4.59
# 1                NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[64000:127999, column] = data.loc[64000:127999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
data_copy = data.copy()

# %%
data_copy.index = range(data.shape[0], data.shape[0] + data_copy.shape[0])

# %%
data = pd.concat([data, data_copy])

# %%
display(data)
# Out:
#         food_name ingredient_name  ingredient_gram  calorie  protein   fat  \
# 0             참꼬막             참꼬막                1    90.79    12.47   2.5
# 1             NaN              쪽파                3      NaN      NaN   NaN
# 2             NaN              마늘                2      NaN      NaN   NaN
# 3             NaN             진간장                5      NaN      NaN   NaN
# 4             NaN             매실청                1      NaN      NaN   NaN
# ...           ...             ...              ...      ...      ...   ...
# 255995        NaN              설탕                3      NaN      NaN   NaN
# 255996        NaN             진간장                1      NaN      NaN   NaN
# 255997  풋고추 된장 무침              고추                4   130.00     9.00  14.0
# 255998        NaN              된장                1      NaN      NaN   NaN
# 255999        NaN              쌈장                1      NaN      NaN   NaN
#
#         carbohydrate
# 0               4.59
# 1                NaN
# ...

# %%
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[128000:255999, column] = data.loc[128000:259999, column].apply(lambda x: x + 1 if isinstance(x, (float, int)) else x)

# %%
# [240000:259999 rows] calroie, protein, fat, carbohydrate + 1000
columns_to_update = ['calorie', 'protein', 'fat', 'carbohydrate']

for column in columns_to_update:
    data.loc[240000:255999, column] = data.loc[240000:259999, column].apply(lambda x: x + 1000 if isinstance(x, (float, int)) else x)

# %%
display(data)
# Out:
#         food_name ingredient_name  ingredient_gram  calorie  protein     fat  \
# 0             참꼬막             참꼬막                1    90.79    12.47     2.5
# 1             NaN              쪽파                3      NaN      NaN     NaN
# 2             NaN              마늘                2      NaN      NaN     NaN
# 3             NaN             진간장                5      NaN      NaN     NaN
# 4             NaN             매실청                1      NaN      NaN     NaN
# ...           ...             ...              ...      ...      ...     ...
# 255995        NaN              설탕                3      NaN      NaN     NaN
# 255996        NaN             진간장                1      NaN      NaN     NaN
# 255997  풋고추 된장 무침              고추                4  1131.00  1010.00  1015.0
# 255998        NaN              된장                1      NaN      NaN     NaN
# 255999        NaN              쌈장                1      NaN      NaN     NaN
#
#         carbohydrate
# 0               4.59
# ...

# %%
# # [220000:239999 rows] calroie, protein, fat, carbohydrate의 값들을 0.1에서 1사이의 랜덤값으로 교체
# minimum_test_data = {
#     'calorie': range(220000, 240000),
#     'protein': range(220000, 240000),
#     'fat': range(220000, 240000),
#     'carbohydrate': range(220000, 240000)
# }

# mtd = pd.DataFrame(minimum_test_data)

# rows_to_change = mtd.index.isin(range(20000))
# columns_to_change = ['calorie', 'protein', 'fat', 'carbohydrate']

# mtd.loc[rows_to_change, columns_to_change] = np.random.uniform(0.1, 1.0, size=(20000, len(columns_to_change)))

# %%
# display(mtd)

# %%
# data.loc[220000:240000]

# %%
# [220000:239999 rows] 0.1에서 1사이의 랜덤한 값으로 calroie, protein, fat, carbohydrate의 기존값 대체
for col in ['calorie', 'protein', 'fat', 'carbohydrate']:
    mask = (data.index >= 220000) & (data.index <= 239999) & data[col].notna()
    random_values = np.random.uniform(0.1, 1, size=mask.sum())
    data.loc[mask, col] = random_values

# %%
data.loc[220000:240000]
# Out:
#         food_name ingredient_name  ingredient_gram      calorie      protein  \
# 220000        참꼬막             참꼬막                1     0.805621     0.782671
# 220001        NaN              쪽파                3          NaN          NaN
# 220002        NaN              마늘                2          NaN          NaN
# 220003        NaN             진간장                5          NaN          NaN
# 220004        NaN             매실청                1          NaN          NaN
# ...           ...             ...              ...          ...          ...
# 239996        NaN             진간장                1          NaN          NaN
# 239997  풋고추 된장 무침              고추                4     0.939914     0.346843
# 239998        NaN              된장                1          NaN          NaN
# 239999        NaN              쌈장                1          NaN          NaN
# 240000        참꼬막             참꼬막                1  1094.790000  1016.470000
#
#                 fat  carbohydrate
# ...

# %%
# data.to_json("final_adult_data.json", orient="split")

# %%
# data.to_csv("final_adult_data.csv", index=True)

# %%
adult_result_df = pd.DataFrame(columns = ["food_name", "ingredient_name", "ingredient_gram", "calorie", "carbohydrate", "protein", "fat"])
flag = False

# %%
cnt = 0

for row in data.iterrows():
    if type(row[1]["food_name"]) == type(""):
        if(flag):
            adult_result_df.loc[cnt] = [food_name, ingredient_name, ingredient_gram, calorie, carbohydrate, protein, fat]
            cnt += 1
            
        food_name = row[1]["food_name"]
        calorie = row[1]["calorie"]
        carbohydrate = row[1]["carbohydrate"]
        protein = row[1]["protein"]
        fat = row[1]["fat"]
        
        ingredient_name = [row[1]["ingredient_name"]]
        ingredient_gram = [row[1]["ingredient_gram"]]
        flag = True
    else:
        ingredient_name.append(row[1]["ingredient_name"])
        ingredient_gram.append(row[1]["ingredient_gram"])

# %%
adult_result_df.loc[cnt] = [food_name, ingredient_name, ingredient_gram, calorie, carbohydrate, protein, fat]

# %%
display(adult_result_df)
# Out:
#        food_name                                    ingredient_name  \
# 0            참꼬막             [참꼬막, 쪽파, 마늘, 진간장, 매실청, 고추가루, 참기름, 참깨]
# 1           부추 전         [부추, 당근, 새우, 고추, 식용유, 부침가루, 물, 멸치액젓, 다진마늘]
# 2           핫 초코                   [우유, 생크림, 슈가파우더, 에소프레소 파우더, 초코렛]
# 3          감자 튀김                              [감자, 소금, 올리브유, 파슬리가루]
# 4       매콤 제육 볶음                [만능 고추장, 삼겹살, 당근, 대파, 양파, 마늘, 고추가루]
# ...          ...                                                ...
# 33787      열무 김치  [열무, 사과, 양파, 고추, 감자, 밑국물, 대파, 다진마늘, 고추가루, 멸치액젓...
# 33788       월남 쌈    [라이스페이퍼, 양파, 파프리카, 깻잎, 당근, 칵테일새우, 버터, 칠리소스, 오이]
# 33789     마늘쫑 볶음                          [마늘쫑, 간장, 물엿, 식용유, 땡초, 물]
# 33790    치킨 데리야끼                        [닭고기, 식용유, 전분, 맛술, 설탕, 진간장]
# 33791  풋고추 된장 무침                                       [고추, 된장, 쌈장]
#
#                                ingredient_gram  calorie  carbohydrate  \
# 0                     [1, 3, 2, 5, 1, 1, 1, 1]    90.79          4.59
# ...

# %%
adult_result_df.to_json("final_adult_data.json", orient="split")
